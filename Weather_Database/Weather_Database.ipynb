# %%
# Import the dependencies.
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np

# %%
# Create a set of random latitude and longitude combinations.
lats = np.random.uniform(low=-90.000, high=90.000, size=2000)
lngs = np.random.uniform(low=-180.000, high=180.000, size=2000)
lat_lngs = zip(lats, lngs)
lat_lngs

# %%
# Add the latitudes and longitudes to a list.
coordinates = list(lat_lngs)

# %%
# Use the citipy module to determine city based on latitude and longitude.
from citipy import citipy

# %%
# Create a list for holding the cities.
cities = []
# Identify the nearest city for each latitude and longitude combination.
for coordinate in coordinates:
    city = citipy.nearest_city(coordinate[0], coordinate[1]).city_name

    # If the city is unique, then we will add it to the cities list.
    if city not in cities:
        cities.append(city)
# Print the city count to confirm sufficient count.
len(cities)
# Out:
# 758

# %%
# Import the requests library.
import requests

# Import the API key.
from config import weather_api_key

# %%
# Starting URL for Weather Map API Call.
url = "http://api.openweathermap.org/data/2.5/weather?units=Imperial&appid=" + weather_api_key

# %%
# Import the time library and the datetime module from the datetime library 
import time
from datetime import datetime

# %%
# Create an empty list to hold the weather data.
city_data = []
# Print the beginning of the logging.
print("Beginning Data Retrieval     ")
print("-----------------------------")

# Create counters.
record_count = 1
set_count = 1

# Loop through all the cities in the list.
for i, city in enumerate(cities):

    # Group cities in sets of 50 for logging purposes.
    if (i % 50 == 0 and i >= 50):
        set_count += 1
        record_count = 1

    # Create endpoint URL with each city.
    city_url = url + "&q=" + city.replace(" ","+")

    # Log the URL, record, and set numbers and the city.
    print(f"Processing Record {record_count} of Set {set_count} | {city}")
    # Add 1 to the record count.
    record_count += 1
    
    # Run an API request for each of the cities.
    try:
        # Parse the JSON and retrieve data.
        city_weather = requests.get(city_url).json()
        # Parse out the needed data.
        city_lat = city_weather["coord"]["lat"]
        city_lng = city_weather["coord"]["lon"]
        city_country = city_weather["sys"]["country"]
        city_max_temp = city_weather["main"]["temp_max"]
        city_humidity = city_weather["main"]["humidity"]
        city_clouds = city_weather["clouds"]["all"]
        city_wind = city_weather["wind"]["speed"]
        city_description = city_weather["weather"][0]["description"]
        
        # Convert the date to ISO standard.
        city_date = datetime.utcfromtimestamp(city_weather["dt"]).strftime('%Y-%m-%d %H:%M:%S')
        
        # Append the city information into city_data list.
        city_data.append({"City": city.title(),
                          "Country": city_country,
                          "Lat": city_lat,
                          "Lng": city_lng,
                          "Max Temp": city_max_temp,
                          "Humidity": city_humidity,
                          "Cloudiness": city_clouds,
                          "Wind Speed": city_wind,
                          "Current Description":city_description })

# If an error is experienced, skip the city.
    except:
        print("City not found. Skipping...")
        pass

# Indicate that Data Loading is complete.
print("-----------------------------")
print("Data Retrieval Complete      ")
print("-----------------------------")
# Out:
# Beginning Data Retrieval
# -----------------------------
# Processing Record 1 of Set 1 | geraldton
# Processing Record 2 of Set 1 | belushya guba
# City not found. Skipping...
# Processing Record 3 of Set 1 | aklavik
# Processing Record 4 of Set 1 | bethel
# Processing Record 5 of Set 1 | port alfred
# Processing Record 6 of Set 1 | waddan
# Processing Record 7 of Set 1 | atuona
# Processing Record 8 of Set 1 | ajdabiya
# Processing Record 9 of Set 1 | new norfolk
# Processing Record 10 of Set 1 | castro
# Processing Record 11 of Set 1 | hunza
# City not found. Skipping...
# Processing Record 12 of Set 1 | verkhnyaya inta
# Processing Record 13 of Set 1 | cape town
# Processing Record 14 of Set 1 | kirakira
# Processing Record 15 of Set 1 | ushuaia
# Processing Record 16 of Set 1 | busselton
# Processing Record 17 of Set 1 | rikitea
# Processing Record 18 of Set 1 | victoria
# Processing Record 19 of Set 1 | vaini
# Processing Record 20 of Set 1 | qena
# Processing Record 21 of Set 1 | nemencine
# Processing Record 22 of Set 1 | upernavik
# Processing Record 23 of Set 1 | coos bay
# Processing Record 24 of Set 1 | lexington
# Processing Record 25 of Set 1 | okhotsk
# Processing Record 26 of Set 1 | yellowknife
# Processing Record 27 of Set 1 | bara
# Processing Record 28 of Set 1 | mataura
# Processing Record 29 of Set 1 | sinnamary
# Processing Record 30 of Set 1 | san patricio
# Processing Record 31 of Set 1 | butaritari
# Processing Record 32 of Set 1 | pangnirtung
# Processing Record 33 of Set 1 | hermanus
# Processing Record 34 of Set 1 | puerto ayora
# Processing Record 35 of Set 1 | mar del plata
# Processing Record 36 of Set 1 | caransebes
# Processing Record 37 of Set 1 | saint-pierre
# Processing Record 38 of Set 1 | kapaa
# Processing Record 39 of Set 1 | kautokeino
# Processing Record 40 of Set 1 | avarua
# Processing Record 41 of Set 1 | vestmannaeyjar
# Processing Record 42 of Set 1 | brigantine
# Processing Record 43 of Set 1 | devils lake
# Processing Record 44 of Set 1 | san policarpo
# Processing Record 45 of Set 1 | barreirinhas
# Processing Record 46 of Set 1 | mahebourg
# Processing Record 47 of Set 1 | qaanaaq
# Processing Record 48 of Set 1 | koscierzyna
# Processing Record 49 of Set 1 | sao filipe
# Processing Record 50 of Set 1 | leningradskiy
# Processing Record 1 of Set 2 | arraial do cabo
# Processing Record 2 of Set 2 | lata
# Processing Record 3 of Set 2 | sarkand
# Processing Record 4 of Set 2 | karasjok
# Processing Record 5 of Set 2 | paamiut
# Processing Record 6 of Set 2 | tabiauea
# City not found. Skipping...
# Processing Record 7 of Set 2 | norman wells
# Processing Record 8 of Set 2 | barrow
# Processing Record 9 of Set 2 | poum
# Processing Record 10 of Set 2 | illoqqortoormiut
# City not found. Skipping...
# Processing Record 11 of Set 2 | saint-georges
# Processing Record 12 of Set 2 | boyolangu
# Processing Record 13 of Set 2 | weligama
# Processing Record 14 of Set 2 | bhainsa
# Processing Record 15 of Set 2 | zhigansk
# Processing Record 16 of Set 2 | sembakung
# Processing Record 17 of Set 2 | gat
# Processing Record 18 of Set 2 | albany
# Processing Record 19 of Set 2 | palabuhanratu
# City not found. Skipping...
# Processing Record 20 of Set 2 | los llanos de aridane
# Processing Record 21 of Set 2 | saint anthony
# Processing Record 22 of Set 2 | prince rupert
# Processing Record 23 of Set 2 | iquique
# Processing Record 24 of Set 2 | bethanien
# Processing Record 25 of Set 2 | bonthe
# Processing Record 26 of Set 2 | ilinskiy
# Processing Record 27 of Set 2 | kodiak
# Processing Record 28 of Set 2 | tecpan
# Processing Record 29 of Set 2 | gejiu
# Processing Record 30 of Set 2 | pasighat
# Processing Record 31 of Set 2 | aksarka
# Processing Record 32 of Set 2 | ferme-neuve
# Processing Record 33 of Set 2 | vaitupu
# City not found. Skipping...
# Processing Record 34 of Set 2 | port hardy
# Processing Record 35 of Set 2 | punta arenas
# Processing Record 36 of Set 2 | thompson
# Processing Record 37 of Set 2 | konibodom
# Processing Record 38 of Set 2 | itoman
# Processing Record 39 of Set 2 | galiwinku
# City not found. Skipping...
# Processing Record 40 of Set 2 | saint-philippe
# Processing Record 41 of Set 2 | andra
# Processing Record 42 of Set 2 | painesville
# Processing Record 43 of Set 2 | sola
# Processing Record 44 of Set 2 | yerbogachen
# Processing Record 45 of Set 2 | arman
# Processing Record 46 of Set 2 | naze
# Processing Record 47 of Set 2 | khatanga
# Processing Record 48 of Set 2 | cabo san lucas
# Processing Record 49 of Set 2 | zaysan
# Processing Record 50 of Set 2 | lorengau
# Processing Record 1 of Set 3 | amderma
# City not found. Skipping...
# Processing Record 2 of Set 3 | clyde river
# Processing Record 3 of Set 3 | segou
# Processing Record 4 of Set 3 | koygorodok
# Processing Record 5 of Set 3 | bluff
# Processing Record 6 of Set 3 | gazanjyk
# Processing Record 7 of Set 3 | basco
# Processing Record 8 of Set 3 | ambilobe
# Processing Record 9 of Set 3 | hervey bay
# Processing Record 10 of Set 3 | plettenberg bay
# Processing Record 11 of Set 3 | sterling
# Processing Record 12 of Set 3 | bathsheba
# Processing Record 13 of Set 3 | kudahuvadhoo
# Processing Record 14 of Set 3 | pokhara
# Processing Record 15 of Set 3 | newcastleton
# Processing Record 16 of Set 3 | bredasdorp
# Processing Record 17 of Set 3 | east london
# Processing Record 18 of Set 3 | riyadh
# Processing Record 19 of Set 3 | inirida
# Processing Record 20 of Set 3 | kristianstad
# Processing Record 21 of Set 3 | dikson
# Processing Record 22 of Set 3 | hilo
# Processing Record 23 of Set 3 | ponta do sol
# Processing Record 24 of Set 3 | chicama
# Processing Record 25 of Set 3 | coihaique
# Processing Record 26 of Set 3 | provideniya
# Processing Record 27 of Set 3 | marzuq
# Processing Record 28 of Set 3 | karpuninskiy
# City not found. Skipping...
# Processing Record 29 of Set 3 | hasaki
# Processing Record 30 of Set 3 | alyangula
# Processing Record 31 of Set 3 | attawapiskat
# City not found. Skipping...
# Processing Record 32 of Set 3 | korla
# Processing Record 33 of Set 3 | port blair
# Processing Record 34 of Set 3 | birao
# Processing Record 35 of Set 3 | tuktoyaktuk
# Processing Record 36 of Set 3 | harper
# Processing Record 37 of Set 3 | taolanaro
# City not found. Skipping...
# Processing Record 38 of Set 3 | iranshahr
# Processing Record 39 of Set 3 | santa lucia
# Processing Record 40 of Set 3 | cherskiy
# Processing Record 41 of Set 3 | codrington
# Processing Record 42 of Set 3 | kisangani
# Processing Record 43 of Set 3 | tamandare
# Processing Record 44 of Set 3 | kushima
# Processing Record 45 of Set 3 | the valley
# Processing Record 46 of Set 3 | lebu
# Processing Record 47 of Set 3 | vao
# Processing Record 48 of Set 3 | hillsborough
# Processing Record 49 of Set 3 | kutum
# Processing Record 50 of Set 3 | mys shmidta
# City not found. Skipping...
# Processing Record 1 of Set 4 | kavieng
# Processing Record 2 of Set 4 | jamestown
# Processing Record 3 of Set 4 | georgetown
# Processing Record 4 of Set 4 | airai
# Processing Record 5 of Set 4 | north bay
# Processing Record 6 of Set 4 | santa ana
# Processing Record 7 of Set 4 | doha
# Processing Record 8 of Set 4 | itaituba
# Processing Record 9 of Set 4 | ambodifototra
# City not found. Skipping...
# Processing Record 10 of Set 4 | ahipara
# Processing Record 11 of Set 4 | hobart
# Processing Record 12 of Set 4 | rocha
# Processing Record 13 of Set 4 | sao joao da barra
# Processing Record 14 of Set 4 | hualmay
# Processing Record 15 of Set 4 | auki
# Processing Record 16 of Set 4 | port macquarie
# Processing Record 17 of Set 4 | yar-sale
# Processing Record 18 of Set 4 | ribeira grande
# Processing Record 19 of Set 4 | saskylakh
# Processing Record 20 of Set 4 | zlitan
# Processing Record 21 of Set 4 | alofi
# Processing Record 22 of Set 4 | novyy urgal
# Processing Record 23 of Set 4 | kruisfontein
# Processing Record 24 of Set 4 | kerman
# Processing Record 25 of Set 4 | chokurdakh
# Processing Record 26 of Set 4 | pevek
# Processing Record 27 of Set 4 | bayanday
# Processing Record 28 of Set 4 | isangel
# Processing Record 29 of Set 4 | grand gaube
# Processing Record 30 of Set 4 | umzimvubu
# City not found. Skipping...
# Processing Record 31 of Set 4 | nikolskoye
# Processing Record 32 of Set 4 | bushenyi
# Processing Record 33 of Set 4 | teknaf
# Processing Record 34 of Set 4 | caconda
# Processing Record 35 of Set 4 | maniago
# Processing Record 36 of Set 4 | marawi
# Processing Record 37 of Set 4 | khandbari
# Processing Record 38 of Set 4 | bandarbeyla
# Processing Record 39 of Set 4 | the pas
# Processing Record 40 of Set 4 | sibolga
# Processing Record 41 of Set 4 | tiksi
# Processing Record 42 of Set 4 | bend
# Processing Record 43 of Set 4 | port elizabeth
# Processing Record 44 of Set 4 | narsaq
# Processing Record 45 of Set 4 | mayor pablo lagerenza
# Processing Record 46 of Set 4 | lukovetskiy
# Processing Record 47 of Set 4 | taoudenni
# Processing Record 48 of Set 4 | mitchell
# Processing Record 49 of Set 4 | emerald
# Processing Record 50 of Set 4 | hirata
# Processing Record 1 of Set 5 | tuy hoa
# Processing Record 2 of Set 5 | quatre cocos
# Processing Record 3 of Set 5 | bambous virieux
# Processing Record 4 of Set 5 | venice
# Processing Record 5 of Set 5 | tapaua
# City not found. Skipping...
# Processing Record 6 of Set 5 | najran
# Processing Record 7 of Set 5 | xining
# Processing Record 8 of Set 5 | ostrovnoy
# Processing Record 9 of Set 5 | ancud
# Processing Record 10 of Set 5 | salalah
# Processing Record 11 of Set 5 | pisco
# Processing Record 12 of Set 5 | saleaula
# City not found. Skipping...
# Processing Record 13 of Set 5 | ponta delgada
# Processing Record 14 of Set 5 | canico
# Processing Record 15 of Set 5 | zlobin
# Processing Record 16 of Set 5 | puerto madero
# Processing Record 17 of Set 5 | berwick
# Processing Record 18 of Set 5 | hamilton
# Processing Record 19 of Set 5 | patitirion
# Processing Record 20 of Set 5 | hun
# Processing Record 21 of Set 5 | abu kamal
# Processing Record 22 of Set 5 | japura
# Processing Record 23 of Set 5 | kaitangata
# Processing Record 24 of Set 5 | beringovskiy
# Processing Record 25 of Set 5 | la playona
# Processing Record 26 of Set 5 | ornskoldsvik
# Processing Record 27 of Set 5 | tasiilaq
# Processing Record 28 of Set 5 | pareora
# Processing Record 29 of Set 5 | hithadhoo
# Processing Record 30 of Set 5 | hobyo
# Processing Record 31 of Set 5 | zlatoust
# Processing Record 32 of Set 5 | benghazi
# Processing Record 33 of Set 5 | katsuura
# Processing Record 34 of Set 5 | barentsburg
# City not found. Skipping...
# Processing Record 35 of Set 5 | axim
# Processing Record 36 of Set 5 | sarakhs
# Processing Record 37 of Set 5 | bengkulu
# Processing Record 38 of Set 5 | pundaguitan
# Processing Record 39 of Set 5 | carnarvon
# Processing Record 40 of Set 5 | chateaubelair
# Processing Record 41 of Set 5 | labutta
# City not found. Skipping...
# Processing Record 42 of Set 5 | cidreira
# Processing Record 43 of Set 5 | marquette
# Processing Record 44 of Set 5 | a
# City not found. Skipping...
# Processing Record 45 of Set 5 | yulara
# Processing Record 46 of Set 5 | hofn
# Processing Record 47 of Set 5 | west plains
# Processing Record 48 of Set 5 | borova
# Processing Record 49 of Set 5 | otane
# Processing Record 50 of Set 5 | saint george
# Processing Record 1 of Set 6 | klyuchi
# Processing Record 2 of Set 6 | avera
# Processing Record 3 of Set 6 | ferkessedougou
# Processing Record 4 of Set 6 | bandundu
# Processing Record 5 of Set 6 | esperance
# Processing Record 6 of Set 6 | oum hadjer
# Processing Record 7 of Set 6 | hambantota
# Processing Record 8 of Set 6 | san rafael
# Processing Record 9 of Set 6 | pozo colorado
# Processing Record 10 of Set 6 | atakpame
# Processing Record 11 of Set 6 | umea
# Processing Record 12 of Set 6 | ojinaga
# Processing Record 13 of Set 6 | tsihombe
# City not found. Skipping...
# Processing Record 14 of Set 6 | yingzhong
# City not found. Skipping...
# Processing Record 15 of Set 6 | longyearbyen
# Processing Record 16 of Set 6 | thinadhoo
# Processing Record 17 of Set 6 | zapolyarnyy
# Processing Record 18 of Set 6 | ontario
# Processing Record 19 of Set 6 | khani
# Processing Record 20 of Set 6 | olinda
# Processing Record 21 of Set 6 | campbeltown
# Processing Record 22 of Set 6 | santa ines
# Processing Record 23 of Set 6 | phan rang
# City not found. Skipping...
# Processing Record 24 of Set 6 | vanimo
# Processing Record 25 of Set 6 | fort nelson
# Processing Record 26 of Set 6 | dillon
# Processing Record 27 of Set 6 | laguna
# Processing Record 28 of Set 6 | garwa
# Processing Record 29 of Set 6 | nome
# Processing Record 30 of Set 6 | kuche
# City not found. Skipping...
# Processing Record 31 of Set 6 | tornio
# Processing Record 32 of Set 6 | lompoc
# Processing Record 33 of Set 6 | nikolsk
# Processing Record 34 of Set 6 | umm jarr
# City not found. Skipping...
# Processing Record 35 of Set 6 | klaksvik
# Processing Record 36 of Set 6 | shelburne
# Processing Record 37 of Set 6 | chernivtsi
# Processing Record 38 of Set 6 | powell river
# Processing Record 39 of Set 6 | baruun-urt
# Processing Record 40 of Set 6 | saurimo
# Processing Record 41 of Set 6 | pandan niog
# Processing Record 42 of Set 6 | takoradi
# Processing Record 43 of Set 6 | vostok
# Processing Record 44 of Set 6 | amarpur
# Processing Record 45 of Set 6 | maldonado
# Processing Record 46 of Set 6 | chernyshevskiy
# Processing Record 47 of Set 6 | maasim
# Processing Record 48 of Set 6 | coxim
# Processing Record 49 of Set 6 | inhambane
# Processing Record 50 of Set 6 | bokspits
# City not found. Skipping...
# Processing Record 1 of Set 7 | ejido
# Processing Record 2 of Set 7 | sorland
# Processing Record 3 of Set 7 | lengshuijiang
# Processing Record 4 of Set 7 | cabedelo
# Processing Record 5 of Set 7 | nemuro
# Processing Record 6 of Set 7 | casa grande
# Processing Record 7 of Set 7 | walvis bay
# Processing Record 8 of Set 7 | grants pass
# Processing Record 9 of Set 7 | palmerston north
# Processing Record 10 of Set 7 | madang
# Processing Record 11 of Set 7 | nanortalik
# Processing Record 12 of Set 7 | dong xoai
# Processing Record 13 of Set 7 | acapulco
# Processing Record 14 of Set 7 | ambon
# Processing Record 15 of Set 7 | agadez
# Processing Record 16 of Set 7 | springville
# Processing Record 17 of Set 7 | alvdal
# Processing Record 18 of Set 7 | nouadhibou
# Processing Record 19 of Set 7 | berbera
# Processing Record 20 of Set 7 | jardim
# Processing Record 21 of Set 7 | vagur
# Processing Record 22 of Set 7 | plainview
# Processing Record 23 of Set 7 | talara
# Processing Record 24 of Set 7 | voznesenye
# Processing Record 25 of Set 7 | ayan
# Processing Record 26 of Set 7 | shaowu
# Processing Record 27 of Set 7 | krasnokamensk
# Processing Record 28 of Set 7 | tayshet
# Processing Record 29 of Set 7 | shingu
# Processing Record 30 of Set 7 | menongue
# Processing Record 31 of Set 7 | angoche
# Processing Record 32 of Set 7 | tabuk
# Processing Record 33 of Set 7 | tuatapere
# Processing Record 34 of Set 7 | tursunzoda
# Processing Record 35 of Set 7 | torbay
# Processing Record 36 of Set 7 | atbasar
# Processing Record 37 of Set 7 | inta
# Processing Record 38 of Set 7 | varnamo
# Processing Record 39 of Set 7 | severo-kurilsk
# Processing Record 40 of Set 7 | dicabisagan
# Processing Record 41 of Set 7 | vestmanna
# Processing Record 42 of Set 7 | xichang
# Processing Record 43 of Set 7 | grenfell
# Processing Record 44 of Set 7 | maghama
# City not found. Skipping...
# Processing Record 45 of Set 7 | bargal
# City not found. Skipping...
# Processing Record 46 of Set 7 | portland
# Processing Record 47 of Set 7 | arona
# Processing Record 48 of Set 7 | ciego de avila
# Processing Record 49 of Set 7 | kenai
# Processing Record 50 of Set 7 | nizhneyansk
# City not found. Skipping...
# Processing Record 1 of Set 8 | luangwa
# Processing Record 2 of Set 8 | jiaozuo
# Processing Record 3 of Set 8 | isla vista
# Processing Record 4 of Set 8 | trairi
# Processing Record 5 of Set 8 | pambujan
# Processing Record 6 of Set 8 | antsohihy
# Processing Record 7 of Set 8 | marang
# Processing Record 8 of Set 8 | belmonte
# Processing Record 9 of Set 8 | puro
# Processing Record 10 of Set 8 | vicuna
# Processing Record 11 of Set 8 | puerto del rosario
# Processing Record 12 of Set 8 | kaeng khlo
# City not found. Skipping...
# Processing Record 13 of Set 8 | ahuimanu
# Processing Record 14 of Set 8 | araouane
# Processing Record 15 of Set 8 | asau
# Processing Record 16 of Set 8 | hovd
# Processing Record 17 of Set 8 | souillac
# Processing Record 18 of Set 8 | mago
# Processing Record 19 of Set 8 | nabire
# Processing Record 20 of Set 8 | kurkino
# Processing Record 21 of Set 8 | porto novo
# Processing Record 22 of Set 8 | puerto suarez
# Processing Record 23 of Set 8 | faanui
# Processing Record 24 of Set 8 | san ramon
# Processing Record 25 of Set 8 | rajshahi
# Processing Record 26 of Set 8 | tutoia
# Processing Record 27 of Set 8 | ushtobe
# Processing Record 28 of Set 8 | guerrero negro
# Processing Record 29 of Set 8 | marcona
# City not found. Skipping...
# Processing Record 30 of Set 8 | muriwai beach
# Processing Record 31 of Set 8 | tongliao
# Processing Record 32 of Set 8 | tumannyy
# City not found. Skipping...
# Processing Record 33 of Set 8 | norfolk
# Processing Record 34 of Set 8 | beloha
# Processing Record 35 of Set 8 | kahului
# Processing Record 36 of Set 8 | mackenzie
# Processing Record 37 of Set 8 | saint-augustin
# Processing Record 38 of Set 8 | hauterive
# Processing Record 39 of Set 8 | reporoa
# Processing Record 40 of Set 8 | asheboro
# Processing Record 41 of Set 8 | ambatolampy
# Processing Record 42 of Set 8 | ukiah
# Processing Record 43 of Set 8 | te anau
# Processing Record 44 of Set 8 | lahij
# Processing Record 45 of Set 8 | new glasgow
# Processing Record 46 of Set 8 | sentyabrskiy
# City not found. Skipping...
# Processing Record 47 of Set 8 | owando
# Processing Record 48 of Set 8 | kurchum
# Processing Record 49 of Set 8 | constitucion
# Processing Record 50 of Set 8 | bousse
# Processing Record 1 of Set 9 | lyantonde
# Processing Record 2 of Set 9 | jacksonville
# Processing Record 3 of Set 9 | kumla
# Processing Record 4 of Set 9 | barabinsk
# Processing Record 5 of Set 9 | boma
# Processing Record 6 of Set 9 | diffa
# Processing Record 7 of Set 9 | ranong
# Processing Record 8 of Set 9 | wilmington
# Processing Record 9 of Set 9 | oistins
# Processing Record 10 of Set 9 | zhangjiakou
# Processing Record 11 of Set 9 | awbari
# Processing Record 12 of Set 9 | kempsey
# Processing Record 13 of Set 9 | margate
# Processing Record 14 of Set 9 | skibbereen
# Processing Record 15 of Set 9 | dryden
# Processing Record 16 of Set 9 | fortuna
# Processing Record 17 of Set 9 | mayo
# Processing Record 18 of Set 9 | santa catarina de tepehuanes
# Processing Record 19 of Set 9 | banos
# Processing Record 20 of Set 9 | manggar
# Processing Record 21 of Set 9 | berthierville
# Processing Record 22 of Set 9 | bayan
# Processing Record 23 of Set 9 | bilibino
# Processing Record 24 of Set 9 | dakar
# Processing Record 25 of Set 9 | half moon bay
# Processing Record 26 of Set 9 | lazaro cardenas
# Processing Record 27 of Set 9 | flinders
# Processing Record 28 of Set 9 | general pico
# Processing Record 29 of Set 9 | khon kaen
# Processing Record 30 of Set 9 | shimoda
# Processing Record 31 of Set 9 | dingle
# Processing Record 32 of Set 9 | champerico
# Processing Record 33 of Set 9 | broken hill
# Processing Record 34 of Set 9 | karratha
# Processing Record 35 of Set 9 | havelock
# Processing Record 36 of Set 9 | coahuayana
# Processing Record 37 of Set 9 | california city
# Processing Record 38 of Set 9 | shakawe
# Processing Record 39 of Set 9 | egvekinot
# Processing Record 40 of Set 9 | natal
# Processing Record 41 of Set 9 | lasa
# Processing Record 42 of Set 9 | qaqortoq
# Processing Record 43 of Set 9 | batya
# Processing Record 44 of Set 9 | ugljevik
# Processing Record 45 of Set 9 | neryungri
# Processing Record 46 of Set 9 | chuy
# Processing Record 47 of Set 9 | ilulissat
# Processing Record 48 of Set 9 | griffith
# Processing Record 49 of Set 9 | tazovskiy
# Processing Record 50 of Set 9 | kaeo
# Processing Record 1 of Set 10 | qurayyat
# Processing Record 2 of Set 10 | agarak
# Processing Record 3 of Set 10 | samusu
# City not found. Skipping...
# Processing Record 4 of Set 10 | lamu
# Processing Record 5 of Set 10 | joura
# Processing Record 6 of Set 10 | lampa
# Processing Record 7 of Set 10 | bandar-e torkaman
# City not found. Skipping...
# Processing Record 8 of Set 10 | waitati
# Processing Record 9 of Set 10 | coquimbo
# Processing Record 10 of Set 10 | taikang
# Processing Record 11 of Set 10 | korba
# Processing Record 12 of Set 10 | iqaluit
# Processing Record 13 of Set 10 | sosnovo-ozerskoye
# Processing Record 14 of Set 10 | mutsamudu
# City not found. Skipping...
# Processing Record 15 of Set 10 | toora-khem
# Processing Record 16 of Set 10 | kodinsk
# Processing Record 17 of Set 10 | umm lajj
# Processing Record 18 of Set 10 | dunedin
# Processing Record 19 of Set 10 | bolshoye nagatkino
# Processing Record 20 of Set 10 | haines junction
# Processing Record 21 of Set 10 | guaraniacu
# Processing Record 22 of Set 10 | hailar
# Processing Record 23 of Set 10 | blackpool
# Processing Record 24 of Set 10 | vila velha
# Processing Record 25 of Set 10 | nambucca heads
# Processing Record 26 of Set 10 | carauari
# Processing Record 27 of Set 10 | imeni poliny osipenko
# Processing Record 28 of Set 10 | petatlan
# Processing Record 29 of Set 10 | wanning
# Processing Record 30 of Set 10 | carmen
# Processing Record 31 of Set 10 | gloucester
# Processing Record 32 of Set 10 | svetlogorsk
# Processing Record 33 of Set 10 | tolaga bay
# Processing Record 34 of Set 10 | lithgow
# Processing Record 35 of Set 10 | tecoanapa
# Processing Record 36 of Set 10 | port hedland
# Processing Record 37 of Set 10 | ruwi
# Processing Record 38 of Set 10 | chilca
# Processing Record 39 of Set 10 | diamantino
# Processing Record 40 of Set 10 | conakry
# Processing Record 41 of Set 10 | moose factory
# Processing Record 42 of Set 10 | colac
# Processing Record 43 of Set 10 | arys
# Processing Record 44 of Set 10 | sulangan
# Processing Record 45 of Set 10 | aswan
# Processing Record 46 of Set 10 | deputatskiy
# Processing Record 47 of Set 10 | praia da vitoria
# Processing Record 48 of Set 10 | hulan
# Processing Record 49 of Set 10 | ayr
# Processing Record 50 of Set 10 | namibe
# Processing Record 1 of Set 11 | nyurba
# Processing Record 2 of Set 11 | praxedis guerrero
# Processing Record 3 of Set 11 | rio gallegos
# Processing Record 4 of Set 11 | gerash
# Processing Record 5 of Set 11 | muros
# Processing Record 6 of Set 11 | la romana
# Processing Record 7 of Set 11 | nara
# Processing Record 8 of Set 11 | phuket
# Processing Record 9 of Set 11 | sabha
# Processing Record 10 of Set 11 | mandalgovi
# Processing Record 11 of Set 11 | buta
# Processing Record 12 of Set 11 | mahibadhoo
# Processing Record 13 of Set 11 | lagoa
# Processing Record 14 of Set 11 | gazni
# City not found. Skipping...
# Processing Record 15 of Set 11 | montabaur
# Processing Record 16 of Set 11 | sechura
# Processing Record 17 of Set 11 | evensk
# Processing Record 18 of Set 11 | palaikastron
# Processing Record 19 of Set 11 | zarubino
# Processing Record 20 of Set 11 | zhangye
# Processing Record 21 of Set 11 | saint-paul
# Processing Record 22 of Set 11 | karatsu
# Processing Record 23 of Set 11 | ambulu
# Processing Record 24 of Set 11 | henties bay
# Processing Record 25 of Set 11 | touros
# Processing Record 26 of Set 11 | aloleng
# Processing Record 27 of Set 11 | faxinal
# Processing Record 28 of Set 11 | fare
# Processing Record 29 of Set 11 | lichinga
# Processing Record 30 of Set 11 | bumba
# Processing Record 31 of Set 11 | ilhabela
# Processing Record 32 of Set 11 | caravelas
# Processing Record 33 of Set 11 | sitka
# Processing Record 34 of Set 11 | kendari
# Processing Record 35 of Set 11 | grand river south east
# City not found. Skipping...
# Processing Record 36 of Set 11 | agucadoura
# Processing Record 37 of Set 11 | chuguyevka
# Processing Record 38 of Set 11 | panzhihua
# Processing Record 39 of Set 11 | pampa
# Processing Record 40 of Set 11 | estelle
# Processing Record 41 of Set 11 | batangafo
# Processing Record 42 of Set 11 | kollam
# Processing Record 43 of Set 11 | dongkan
# Processing Record 44 of Set 11 | tokmak
# Processing Record 45 of Set 11 | teguldet
# Processing Record 46 of Set 11 | ostrow mazowiecka
# Processing Record 47 of Set 11 | irbeyskoye
# Processing Record 48 of Set 11 | viedma
# Processing Record 49 of Set 11 | vaitape
# Processing Record 50 of Set 11 | jacareacanga
# Processing Record 1 of Set 12 | namatanai
# Processing Record 2 of Set 12 | ampanihy
# Processing Record 3 of Set 12 | longavi
# Processing Record 4 of Set 12 | camacha
# Processing Record 5 of Set 12 | hailey
# Processing Record 6 of Set 12 | puerto cabezas
# Processing Record 7 of Set 12 | lulea
# Processing Record 8 of Set 12 | guozhen
# Processing Record 9 of Set 12 | harrisonville
# Processing Record 10 of Set 12 | atasu
# Processing Record 11 of Set 12 | ust-ilimsk
# Processing Record 12 of Set 12 | luderitz
# Processing Record 13 of Set 12 | eskilstuna
# Processing Record 14 of Set 12 | hihya
# Processing Record 15 of Set 12 | carutapera
# Processing Record 16 of Set 12 | yerofey pavlovich
# Processing Record 17 of Set 12 | adrar
# Processing Record 18 of Set 12 | hay river
# Processing Record 19 of Set 12 | seka
# Processing Record 20 of Set 12 | qasigiannguit
# Processing Record 21 of Set 12 | kasongo-lunda
# Processing Record 22 of Set 12 | bombay
# Processing Record 23 of Set 12 | vammala
# Processing Record 24 of Set 12 | hovorany
# Processing Record 25 of Set 12 | alice springs
# Processing Record 26 of Set 12 | tual
# Processing Record 27 of Set 12 | gushikawa
# Processing Record 28 of Set 12 | umm durman
# City not found. Skipping...
# Processing Record 29 of Set 12 | rincon
# Processing Record 30 of Set 12 | pangoa
# Processing Record 31 of Set 12 | mount gambier
# Processing Record 32 of Set 12 | pasni
# Processing Record 33 of Set 12 | sukhothai
# Processing Record 34 of Set 12 | havoysund
# Processing Record 35 of Set 12 | novo cruzeiro
# Processing Record 36 of Set 12 | yeppoon
# Processing Record 37 of Set 12 | khasan
# Processing Record 38 of Set 12 | hongjiang
# Processing Record 39 of Set 12 | cayenne
# Processing Record 40 of Set 12 | aflu
# City not found. Skipping...
# Processing Record 41 of Set 12 | petropavlovka
# Processing Record 42 of Set 12 | alta floresta
# Processing Record 43 of Set 12 | ipora
# Processing Record 44 of Set 12 | kawalu
# Processing Record 45 of Set 12 | feira de santana
# Processing Record 46 of Set 12 | amazar
# Processing Record 47 of Set 12 | shenjiamen
# Processing Record 48 of Set 12 | dospat
# Processing Record 49 of Set 12 | kontagora
# Processing Record 50 of Set 12 | tres arroyos
# Processing Record 1 of Set 13 | ternate
# Processing Record 2 of Set 13 | morlaix
# Processing Record 3 of Set 13 | el faiyum
# City not found. Skipping...
# Processing Record 4 of Set 13 | shadegan
# Processing Record 5 of Set 13 | mangrol
# Processing Record 6 of Set 13 | bida
# Processing Record 7 of Set 13 | spasskoye
# Processing Record 8 of Set 13 | genhe
# Processing Record 9 of Set 13 | fuxin
# Processing Record 10 of Set 13 | opuwo
# Processing Record 11 of Set 13 | letlhakane
# Processing Record 12 of Set 13 | cap malheureux
# Processing Record 13 of Set 13 | cockburn town
# Processing Record 14 of Set 13 | morro bay
# Processing Record 15 of Set 13 | nohar
# Processing Record 16 of Set 13 | ocos
# Processing Record 17 of Set 13 | yelan-kolenovskiy
# Processing Record 18 of Set 13 | saldanha
# Processing Record 19 of Set 13 | bilma
# Processing Record 20 of Set 13 | elliot lake
# Processing Record 21 of Set 13 | salina cruz
# Processing Record 22 of Set 13 | magaria
# Processing Record 23 of Set 13 | port lincoln
# Processing Record 24 of Set 13 | kalispell
# Processing Record 25 of Set 13 | pagudpud
# Processing Record 26 of Set 13 | odweyne
# Processing Record 27 of Set 13 | howard springs
# Processing Record 28 of Set 13 | troy
# Processing Record 29 of Set 13 | goderich
# Processing Record 30 of Set 13 | panguna
# Processing Record 31 of Set 13 | grindavik
# Processing Record 32 of Set 13 | dharchula
# Processing Record 33 of Set 13 | warqla
# City not found. Skipping...
# Processing Record 34 of Set 13 | takaka
# Processing Record 35 of Set 13 | khandyga
# Processing Record 36 of Set 13 | susanville
# Processing Record 37 of Set 13 | atherton
# Processing Record 38 of Set 13 | formosa do rio preto
# Processing Record 39 of Set 13 | wasilla
# Processing Record 40 of Set 13 | rawson
# Processing Record 41 of Set 13 | waipawa
# Processing Record 42 of Set 13 | sibi
# Processing Record 43 of Set 13 | rosolini
# Processing Record 44 of Set 13 | dubenskiy
# City not found. Skipping...
# Processing Record 45 of Set 13 | whyalla
# Processing Record 46 of Set 13 | zemio
# Processing Record 47 of Set 13 | vallenar
# Processing Record 48 of Set 13 | mazagao
# Processing Record 49 of Set 13 | los andes
# Processing Record 50 of Set 13 | sabang
# Processing Record 1 of Set 14 | taksimo
# Processing Record 2 of Set 14 | pontianak
# Processing Record 3 of Set 14 | mundwa
# Processing Record 4 of Set 14 | mikkeli
# Processing Record 5 of Set 14 | buckeye
# Processing Record 6 of Set 14 | morgan city
# Processing Record 7 of Set 14 | falam
# Processing Record 8 of Set 14 | dzhusaly
# City not found. Skipping...
# Processing Record 9 of Set 14 | nguiu
# City not found. Skipping...
# Processing Record 10 of Set 14 | camabatela
# Processing Record 11 of Set 14 | pangai
# Processing Record 12 of Set 14 | lensk
# Processing Record 13 of Set 14 | standerton
# Processing Record 14 of Set 14 | nalut
# Processing Record 15 of Set 14 | mutis
# Processing Record 16 of Set 14 | lavrentiya
# Processing Record 17 of Set 14 | uhlove
# Processing Record 18 of Set 14 | arlit
# Processing Record 19 of Set 14 | bosconia
# Processing Record 20 of Set 14 | bonavista
# Processing Record 21 of Set 14 | nenjiang
# Processing Record 22 of Set 14 | kamina
# Processing Record 23 of Set 14 | la rioja
# Processing Record 24 of Set 14 | luanda
# Processing Record 25 of Set 14 | chama
# Processing Record 26 of Set 14 | bendigo
# Processing Record 27 of Set 14 | nangomba
# Processing Record 28 of Set 14 | kiama
# Processing Record 29 of Set 14 | tezu
# Processing Record 30 of Set 14 | kathu
# Processing Record 31 of Set 14 | tuensang
# Processing Record 32 of Set 14 | eureka
# Processing Record 33 of Set 14 | palanga
# Processing Record 34 of Set 14 | butembo
# Processing Record 35 of Set 14 | gaziantep
# Processing Record 36 of Set 14 | san juan
# Processing Record 37 of Set 14 | ardakan
# Processing Record 38 of Set 14 | buchanan
# Processing Record 39 of Set 14 | dana point
# Processing Record 40 of Set 14 | ocean city
# Processing Record 41 of Set 14 | boralday
# Processing Record 42 of Set 14 | rheinau
# Processing Record 43 of Set 14 | wewak
# Processing Record 44 of Set 14 | fuchu
# Processing Record 45 of Set 14 | buala
# Processing Record 46 of Set 14 | zhemchuzhnyy
# City not found. Skipping...
# Processing Record 47 of Set 14 | potgietersrus
# City not found. Skipping...
# Processing Record 48 of Set 14 | guangyuan
# Processing Record 49 of Set 14 | kieta
# Processing Record 50 of Set 14 | key largo
# Processing Record 1 of Set 15 | aldan
# Processing Record 2 of Set 15 | orbetello
# Processing Record 3 of Set 15 | kosh-agach
# Processing Record 4 of Set 15 | malanje
# Processing Record 5 of Set 15 | shiraoi
# Processing Record 6 of Set 15 | tanabe
# Processing Record 7 of Set 15 | pochutla
# Processing Record 8 of Set 15 | broome
# Processing Record 9 of Set 15 | westport
# Processing Record 10 of Set 15 | depok
# Processing Record 11 of Set 15 | tarudant
# City not found. Skipping...
# Processing Record 12 of Set 15 | banda aceh
# Processing Record 13 of Set 15 | matara
# Processing Record 14 of Set 15 | hwange
# Processing Record 15 of Set 15 | almaznyy
# Processing Record 16 of Set 15 | sao geraldo do araguaia
# Processing Record 17 of Set 15 | lyudinovo
# Processing Record 18 of Set 15 | okha
# Processing Record 19 of Set 15 | lichtenau
# Processing Record 20 of Set 15 | turukhansk
# Processing Record 21 of Set 15 | san cristobal
# Processing Record 22 of Set 15 | hami
# Processing Record 23 of Set 15 | zhanatas
# City not found. Skipping...
# Processing Record 24 of Set 15 | salinopolis
# Processing Record 25 of Set 15 | saint-joseph
# Processing Record 26 of Set 15 | eenhana
# Processing Record 27 of Set 15 | lafiagi
# Processing Record 28 of Set 15 | petropavlovsk-kamchatskiy
# Processing Record 29 of Set 15 | tuggurt
# City not found. Skipping...
# Processing Record 30 of Set 15 | grand centre
# City not found. Skipping...
# Processing Record 31 of Set 15 | letnik
# Processing Record 32 of Set 15 | seymchan
# Processing Record 33 of Set 15 | mount isa
# Processing Record 34 of Set 15 | college
# Processing Record 35 of Set 15 | acari
# Processing Record 36 of Set 15 | moyale
# Processing Record 37 of Set 15 | astoria
# Processing Record 38 of Set 15 | bima
# Processing Record 39 of Set 15 | tura
# Processing Record 40 of Set 15 | uzhur
# Processing Record 41 of Set 15 | ulladulla
# Processing Record 42 of Set 15 | bath
# Processing Record 43 of Set 15 | santa maria
# Processing Record 44 of Set 15 | guaiba
# Processing Record 45 of Set 15 | tateyama
# Processing Record 46 of Set 15 | lydenburg
# Processing Record 47 of Set 15 | balkanabat
# Processing Record 48 of Set 15 | matay
# Processing Record 49 of Set 15 | dangeni
# Processing Record 50 of Set 15 | belyy yar
# Processing Record 1 of Set 16 | whitehorse
# Processing Record 2 of Set 16 | sangueya
# Processing Record 3 of Set 16 | yumen
# Processing Record 4 of Set 16 | bournemouth
# Processing Record 5 of Set 16 | port hawkesbury
# Processing Record 6 of Set 16 | bruntal
# Processing Record 7 of Set 16 | zelenogorskiy
# Processing Record 8 of Set 16 | aripuana
# -----------------------------
# Data Retrieval Complete
# -----------------------------

# %%
# Convert the array of dictionaries to a Pandas DataFrame.
city_data_df = pd.DataFrame(city_data)
city_data_df.head(10)
# Out:
#               City Country      Lat       Lng  Max Temp  Humidity  Cloudiness  \
# 0        Geraldton      AU -28.7667  114.6000     97.21        17         100
# 1          Aklavik      CA  68.2191 -135.0107      0.32        95         100
# 2           Bethel      US  41.3712  -73.4140     41.99        69           7
# 3      Port Alfred      ZA -33.5906   26.8910     70.52        84          93
# 4           Waddan      LY  29.1614   16.1390     56.55        37          97
# 5           Atuona      PF  -9.8000 -139.0333     78.64        74          78
# 6         Ajdabiya      LY  30.7554   20.2263     54.61        52          72
# 7      New Norfolk      AU -42.7826  147.0587     64.71        29          19
# 8           Castro      BR -24.7911  -50.0119     65.93        62          46
# 9  Verkhnyaya Inta      RU  65.9811   60.3094     -1.89        82          69
#
#    Wind Speed Current Description
# 0       21.85     overcast clouds
# 1       21.65                snow
# 2        1.01           clear sky
# 3        1.72     overcast clouds
# 4        5.61     overcast clouds
# 5       16.26       broken clouds
# 6        9.80       broken clouds
# 7        3.62          few clouds
# 8        3.02    scattered clouds
# 9        8.97       broken clouds

# %%
# Create the output file (CSV).
output_data_file = "Weather_Database/WeatherPy_Database.csv"

# Export the City_Data into a CSV.
city_data_df.to_csv(output_data_file, index_label="City_ID")
